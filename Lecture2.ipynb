# %% [markdown]
# # Sum of two numbers

# %%
a = 4 
b = 6
print (a+b)
# Out:
# 10

# %% [markdown]
# # Integer Data Type
# #### It is use for store integer values like negative numbers to posative numbers

# %%
a = 789
b = 890
c = 900

# %% [markdown]
# # string Data Type

# %%
name = "AliHusnainNazarMuhammad"
print(name[-1])
print (name[3])
# Out:
# d
# H

# %%
name = "AliHusnainNazarMuhammad"
print(name*10)
print(len(name))
# Out:
# AliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammadAliHusnainNazarMuhammad
# 23

# %%
name = "AliHusnainNazarMuhammad"
print("w"in name )
print("Ali"in name )
# Out:
# False
# True

# %% [markdown]
# # len()

# %%
name = "ALi Hu"
print(len(name))
# Out:
# 6

# %% [markdown]
# # upper()

# %%
name = "ALi Hu".upper()
print(name.upper())
``
# Out:
# ALI HU

# %% [markdown]
# # lower()

# %%
name = "ALi Hu".lower()
print(name.lower())
# Out:
# ali hu

# %%
name = """
ALi Hunain is a good player and he play cricket. 
He is a Bowler."""
print(name)
# Out:
# ALi Hunain is a good player and he play cricket.
# He is a Bowler.

# %% [markdown]
# # replace()

# %%
name = """
ALi Hunain is a good player and he play cricket. 
He is a Bowler."""
print(name.replace('Bowler','Batsman'))
# Out:
# ALi Hunain is a good player and he play cricket.
# He is a Batsman.

# %%
name = """
ALi,Hunain,is a good player and he play cricket. 
He is a Bowler.""".split(",")
print(name)
# Out:
# ['\nALi', 'Hunain', 'is a good player and he play cricket. \nHe is a Bowler.']

# %%
name = """
ALi Hunain is a good player and he play cricket. 
He is a Bowler."""
print(name.replace(" ",","))
name.split()
# Out:
# ALi,Hunain,is,a,good,player,and,he,play,cricket.,
# He,is,a,Bowler.
# ['ALi',
#  'Hunain',
#  'is',
#  'a',
#  'good',
#  'player',
#  'and',
#  'he',
#  'play',
#  'cricket.',
#  'He',
#  'is',
#  'a',
#  'Bowler.']

# %%
name = "ali talha danish umer hamza hassnat"
print(name.find("umer"))
# Out:
# 17

# %%
adress = "/U00BD"
num = "5678"
print(adress.isdigit())
print(num.isdigit())
# Out:
# False
# True

# %%
name = "ALI HUSNAIN"
print(name.islower())
# Out:
# False

# %%
name = "ALI HUSNAIN"
print(name.isupper())
# Out:
# True

# %% [markdown]
# # Boolean

# %%
is_active = True
python_exist = False
age = 18
print(age == 18)
print(age!=19)
print(age!=18)
# Out:
# True
# True
# False
