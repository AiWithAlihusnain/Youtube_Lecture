# %% [markdown]
# # oops

# %%
class Player:
    def __init__ (self, name, health, weapon):
        self.name = name
        self.health = health
        self.weapon = weapon
    def attack(self):
        print(f"{self.name} ne {self.weapon} se attack kiya!")

p1 = Player("oriono", 100, "Desert Eagle")
p2 = Player("Sonia", 150, "AK-47")
p1.attack()
p2.attack()
# Out:
# oriono ne Desert Eagle se attack kiya!
# Sonia ne AK-47 se attack kiya!

# %%
sonia = Player("Sonia", 150, "AK-47")
oriono = Player("oriono", 100, "Desert Eagle")
