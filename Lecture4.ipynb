# %% [markdown]
# # Lecture 4
# ## While Loop
# ## Functions

# %%
i = 1
while i <=5:
    print(i)
    i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
password = ""
while password != "Python123":
    password = input ("Enter Your Password: ")
print ("Access Granted")
# Out:
# Access Granted

# %%
def greet():
    print("Hello,Welcome to python day 4")

# %%
greet()
# Out:
# Hello,Welcome to python day 4

# %%
def greet(name):
    print("Hello",name)

# %%
greet("Ali")
greet("sira")
greet("ayesha")
# Out:
# Hello Ali
# Hello sira
# Hello ayesha

# %%
def add(a , b):
    print(a+b)

# %%
add(2,4)
add(2,3)
# Out:
# 6
# 5

# %% [markdown]
# # calculator

# %%
def add(a,b):
    return a + b
def subtract(a,b):
    return a - b
def multiply(a,b):
    return a*b
def divide(a,b):
    if b == 0:
        return "Error: Division by zero became infinite"
    return a / b
while True:
    print("\n Simple Calculator")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Exit")
    choice = input ("Enter Your Choice (1-5)")
    if choice == "5":
        print("Calculator Closed")
        break
    a = int(input ("enter first number"))
    b = int(input ("secound number"))
    if choice == "1":
        print("Result",add(a,b))
    elif choice == "2":
        print("Result",subtract(a,b))
    elif choice == "3":
        print("Result",multiply(a,b))
    elif choice == "4":
        print("Result",divide(a,b))
    else:
        print("Invalid choice,Please enter from 1-5")
# Out:
#  Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Result 5
#
#  Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Invalid choice,Please enter from 1-5
#
#  Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 23
#      21     break
#      22 a = int(input ("enter first number"))
# ---> 23 b = int(input ("secound number"))
#      24 if choice == "1":
#      25     print("Result",add(a,b))
#
# ValueError: invalid literal for int() with base 10: 'u7'

# %%
import tkinter as tk

# Main window
root = tk.Tk()
root.title("GUI Calculator")
root.geometry("300x400")
root.resizable(False, False)

# Entry field
entry = tk.Entry(root, font=("Arial", 20), borderwidth=5, relief="ridge", justify="right")
entry.pack(fill="both", ipadx=8, ipady=15, padx=10, pady=10)

# Function to add value to entry
def click(value):
    entry.insert(tk.END, value)

# Function to clear entry
def clear():
    entry.delete(0, tk.END)

# Function to calculate result
def calculate():
    try:
        result = eval(entry.get())
        clear()
        entry.insert(0, result)
    except ZeroDivisionError:
        clear()
        entry.insert(0, "Error")
    except:
        clear()
        entry.insert(0, "Invalid")

# Buttons frame
frame = tk.Frame(root)
frame.pack()

# Button layout
buttons = [
    ('7', '8', '9', '/'),
    ('4', '5', '6', '*'),
    ('1', '2', '3', '-'),
    ('0', '.', '=', '+')
]

# Create buttons
for row in buttons:
    row_frame = tk.Frame(frame)
    row_frame.pack(expand=True, fill="both")
    for btn in row:
        action = lambda x=btn: calculate() if x == '=' else click(x)
        tk.Button(
            row_frame,
            text=btn,
            font=("Arial", 16),
            height=2,
            width=5,
            command=action
        ).pack(side="left", expand=True, fill="both")

# Clear button
tk.Button(
    root,
    text="Clear",
    font=("Arial", 16),
    bg="red",
    fg="white",
    command=clear
).pack(fill="both", padx=10, pady=10)

# Run app
root.mainloop()
